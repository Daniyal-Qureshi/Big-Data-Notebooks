# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %%
spark = SparkSession.builder.appName("SQL Practice").config('spark.sql.shuffle.partitions','20').getOrCreate()

# %%
df = spark.read.parquet("../notebooks/weather.2016.parquet")

# %%
df.printSchema()
# Out:
# root
#  |-- ForecastSiteCode: long (nullable = true)
#  |-- ObservationTime: long (nullable = true)
#  |-- ObservationDate: timestamp (nullable = true)
#  |-- WindDirection: long (nullable = true)
#  |-- WindSpeed: long (nullable = true)
#  |-- WindGust: double (nullable = true)
#  |-- Visibility: double (nullable = true)
#  |-- ScreenTemperature: double (nullable = true)
#  |-- Pressure: double (nullable = true)
#  |-- SignificantWeatherCode: long (nullable = true)
#  |-- SiteName: string (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)

# %%
df.rdd.getNumPartitions()
# Out:
# 1

# %%
df_partitioned = df.repartition(8)

# %%
df_partitioned.rdd.getNumPartitions()
# Out:
# 8

# %%
df_partitioned.printSchema()
# Out:
# root
#  |-- ForecastSiteCode: long (nullable = true)
#  |-- ObservationTime: long (nullable = true)
#  |-- ObservationDate: timestamp (nullable = true)
#  |-- WindDirection: long (nullable = true)
#  |-- WindSpeed: long (nullable = true)
#  |-- WindGust: double (nullable = true)
#  |-- Visibility: double (nullable = true)
#  |-- ScreenTemperature: double (nullable = true)
#  |-- Pressure: double (nullable = true)
#  |-- SignificantWeatherCode: long (nullable = true)
#  |-- SiteName: string (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)

# %%
df_partitioned.rdd.getNumPartitions()
# Out:
# 8

# %%
df_partitioned.rdd.glom().map(len).collect()
# Out:
# [24337, 24337, 24337, 24337, 24337, 24337, 24338, 24337]

# %%
print(df_partitioned.columns)
# Out:
# ['ForecastSiteCode', 'ObservationTime', 'ObservationDate', 'WindDirection', 'WindSpeed', 'WindGust', 'Visibility', 'ScreenTemperature', 'Pressure', 'SignificantWeatherCode', 'SiteName', 'Latitude', 'Longitude', 'Region', 'Country']

# %%
# Out:
# +----------------+---------------+-------------------+-------------+---------+--------+----------+-----------------+--------+----------------------+------------------+--------+---------+--------------------+----------------+
# |ForecastSiteCode|ObservationTime|    ObservationDate|WindDirection|WindSpeed|WindGust|Visibility|ScreenTemperature|Pressure|SignificantWeatherCode|          SiteName|Latitude|Longitude|              Region|         Country|
# +----------------+---------------+-------------------+-------------+---------+--------+----------+-----------------+--------+----------------------+------------------+--------+---------+--------------------+----------------+
# |            3379|             20|2016-02-29 05:00:00|            8|        9|    null|   29000.0|              4.7|  1023.0|                     8|   CRANWELL (3379)|   53.03|     -0.5|       East Midlands|            null|
# |            3171|             22|2016-02-07 05:00:00|            8|       10|    null|   45000.0|              4.0|   968.0|                    12|   LEUCHARS (3171)|  56.377|   -2.862|Central Tayside &...|        SCOTLAND|
# |            3100|              6|2016-02-05 05:00:00|            8|       31|    39.0|    5000.0|              8.7|  1002.0|                    12|      TIREE (3100)|  56.497|   -6.887|         Strathclyde|        SCOTLAND|
# |            3224|             17|2016-03-08 05:00:00|           11|       14|    null|   12000.0|              4.8|  1004.0|                     8|  SPADEADAM (3224)|   55.05|   -2.553|  North West England|         ENGLAND|
# |            3507|             17|2016-02-15 05:00:00|            0|        2|    null|   35000.0|              2.7|  1032.0|                     1|SENNYBRIDGE (3507)|  52.063|   -3.614|               Wales|           WALES|
# |            3224|             15|2016-02-16 05:00:00|           10|       29|    43.0|   24000.0|              2.2|  1021.0|                     7|  SPADEADAM (3224)|   55.05|   -2.553|  North West England|         ENGLAND|
# |            3917|             22|2016-03-20 05:00:00|            1|        1|    null|   12000.0|              3.3|  1026.0|                     0| ALDERGROVE (3917)|  54.664|   -6.224|    Northern Ireland|NORTHERN IRELAND|
# |            3488|              3|2016-03-19 05:00:00|            0|       16|    null|   12000.0|              6.1|  1026.0|                     7|  WEYBOURNE (3488)|  52.949|    1.127|     East of England|         ENGLAND|
# |            3522|             22|2016-02-09 05:00:00|           12|       14|    25.0|   45000.0|              4.4|   988.0|                     7|   HEREFORD (3522)|  52.083|     -2.8|       West Midlands|         ENGLAND|
# |            3462|             18|2016-02-22 05:00:00|           12|        8|    null|   65000.0|              3.8|  1009.0|                     7|  WITTERING (3462)|  52.611|   -0.459|     East of England|         ENGLAND|
# +----------------+---------------+-------------------+-------------+---------+--------+----------+-----------------+--------+----------------------+------------------+--------+---------+--------------------+----------------+
# only showing top 10 rows

# %%
df_p1 = df_partitioned.select('region','country').distinct()

# %%
df_p1.rdd.getNumPartitions()
# Out:
# 20

# %%
partition1 = df_partitioned.repartition('country')

# %%
df_partitioned.select('country').distinct().show()
# Out:
# +----------------+
# |         country|
# +----------------+
# |            null|
# |        SCOTLAND|
# |         ENGLAND|
# |     ISLE OF MAN|
# |           WALES|
# |NORTHERN IRELAND|
# +----------------+

# %%
partition1.rdd.getNumPartitions()
# Out:
# 20

# %%
partition1.rdd.glom().map(len).collect()
# Out:
# [0,
#  0,
#  19280,
#  0,
#  0,
#  40945,
#  0,
#  0,
#  0,
#  0,
#  103192,
#  0,
#  1433,
#  0,
#  18437,
#  0,
#  0,
#  11410,
#  0,
#  0]

# %%
partition1.rdd.glom().map(len).collect()
# Out:
# [1435,
#  1423,
#  1420,
#  2825,
#  0,
#  0,
#  4277,
#  0,
#  1362,
#  0,
#  0,
#  1427,
#  0,
#  1311,
#  0,
#  0,
#  1313,
#  1432,
#  1432,
#  0,
#  1430,
#  4198,
#  1430,
#  0,
#  2854,
#  0,
#  0,
#  1437,
#  0,
#  0,
#  1431,
#  0,
#  0,
#  0,
#  0,
#  1421,
#  2815,
#  2832,
#  1429,
#  0,
#  2866,
#  0,
#  0,
#  1425,
#  0,
#  0,
#  0,
#  0,
#  1433,
#  0,
#  1423,
#  1436,
#  0,
#  1430,
#  2829,
#  0,
#  1434,
#  1418,
#  1424,
#  0,
#  1267,
#  0,
#  0,
#  1428,
#  0,
#  2846,
#  0,
#  1418,
#  0,
#  0,
#  0,
#  0,
#  1433,
#  0,
#  1425,
#  1372,
#  0,
#  0,
#  1431,
#  0,
#  0,
#  1413,
#  2714,
#  1435,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1436,
#  4298,
#  0,
#  1436,
#  0,
#  1527,
#  0,
#  0,
#  0,
#  0,
#  1386,
#  1429,
#  1424,
#  2866,
#  1412,
#  2798,
#  0,
#  2831,
#  0,
#  0,
#  1403,
#  0,
#  1432,
#  0,
#  0,
#  0,
#  1106,
#  1426,
#  0,
#  1429,
#  0,
#  1432,
#  0,
#  1392,
#  0,
#  1354,
#  1429,
#  0,
#  0,
#  0,
#  0,
#  1431,
#  0,
#  2824,
#  0,
#  0,
#  0,
#  1389,
#  1419,
#  0,
#  4089,
#  2860,
#  1429,
#  0,
#  2831,
#  0,
#  1412,
#  2826,
#  0,
#  0,
#  1424,
#  1431,
#  0,
#  1424,
#  0,
#  0,
#  0,
#  4248,
#  0,
#  2852,
#  4266,
#  1430,
#  1407,
#  0,
#  0,
#  1431,
#  7098,
#  0,
#  0,
#  2822,
#  0,
#  0,
#  0,
#  1433,
#  0,
#  1297,
#  1434,
#  2724,
#  1419,
#  1315,
#  0,
#  0,
#  0,
#  0,
#  0,
#  2824,
#  0,
#  0,
#  1422,
#  0,
#  1420,
#  5716,
#  0,
#  1407,
#  0,
#  0,
#  1420,
#  4293,
#  2750,
#  0,
#  0]

# %%
partition1.rdd.glom().collect()
# Out:
# [[Row(ForecastSiteCode=3002, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=8, WindGust=None, Visibility=30000.0, ScreenTemperature=2.1, Pressure=997.0, SignificantWeatherCode=8, SiteName='BALTASOUND (3002)', Latitude=60.749, Longitude=-0.854, Region='Orkney & Shetland', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3005, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=2, WindGust=None, Visibility=35000.0, ScreenTemperature=0.1, Pressure=997.0, SignificantWeatherCode=7, SiteName='LERWICK (S. SCREEN) (3005)', Latitude=60.139, Longitude=-1.183, Region='Orkney & Shetland', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3023, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=30, WindGust=37.0, Visibility=2600.0, ScreenTemperature=9.8, Pressure=991.0, SignificantWeatherCode=11, SiteName='SOUTH UIST RANGE (3023)', Latitude=57.358, Longitude=-7.397, Region='Highland & Eilean Siar', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3041, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=44, WindGust=82.0, Visibility=None, ScreenTemperature=3.9, Pressure=None, SignificantWeatherCode=-99, SiteName='AONACH MOR (3041)', Latitude=56.82, Longitude=-4.97, Region='Highland & Eilean Siar', Country=None),
#   Row(ForecastSiteCode=3063, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=9, WindSpeed=9, WindGust=22.0, Visibility=22000.0, ScreenTemperature=2.7, Pressure=996.0, SignificantWeatherCode=9, SiteName='AVIEMORE (3063)', Latitude=57.206, Longitude=-3.827, Region='Highland & Eilean Siar', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3075, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=7, WindSpeed=10, WindGust=None, Visibility=27000.0, ScreenTemperature=4.2, Pressure=996.0, SignificantWeatherCode=8, SiteName='WICK AIRPORT (3075)', Latitude=58.454, Longitude=-3.089, Region='Highland & Eilean Siar', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3068, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=6, WindSpeed=8, WindGust=None, Visibility=23000.0, ScreenTemperature=2.5, Pressure=996.0, SignificantWeatherCode=8, SiteName='LOSSIEMOUTH (3068)', Latitude=57.712, Longitude=-3.322, Region='Grampian', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3080, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=2, WindGust=None, Visibility=16000.0, ScreenTemperature=0.8, Pressure=998.0, SignificantWeatherCode=7, SiteName='ABOYNE (3080)', Latitude=57.077, Longitude=-2.836, Region='Grampian', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3105, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=26, WindGust=39.0, Visibility=11000.0, ScreenTemperature=10.3, Pressure=999.0, SignificantWeatherCode=8, SiteName='ISLAY/PORT ELLEN (3105)', Latitude=55.681, Longitude=-6.256, Region='Strathclyde', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3136, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=23, WindGust=33.0, Visibility=3700.0, ScreenTemperature=10.4, Pressure=1000.0, SignificantWeatherCode=11, SiteName='PRESTWICK RNAS (3136)', Latitude=55.515, Longitude=-4.585, Region='Strathclyde', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3155, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=22, WindGust=29.0, Visibility=10000.0, ScreenTemperature=8.9, Pressure=999.0, SignificantWeatherCode=8, SiteName='DRUMALBIN (3155)', Latitude=55.627, Longitude=-3.735, Region='Strathclyde', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3153, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=32, WindGust=43.0, Visibility=3800.0, ScreenTemperature=9.5, Pressure=1002.0, SignificantWeatherCode=8, SiteName='DUNDRENNAN (3153)', Latitude=54.803, Longitude=-4.008, Region='Dumfries, Galloway', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3166, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=13, WindSpeed=5, WindGust=None, Visibility=2500.0, ScreenTemperature=4.5, Pressure=998.0, SignificantWeatherCode=11, SiteName='EDINBURGH/GOGARBANK (3166)', Latitude=55.928, Longitude=-3.343, Region='Dumfries, Galloway', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3911, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=37.0, Visibility=13000.0, ScreenTemperature=9.7, Pressure=1002.0, SignificantWeatherCode=8, SiteName='LOUGH FEA (3911)', Latitude=54.72, Longitude=-6.82, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=3916, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=32, WindGust=45.0, Visibility=29000.0, ScreenTemperature=10.5, Pressure=1000.0, SignificantWeatherCode=8, SiteName='BALLYPATRICK FOREST (3916)', Latitude=55.181, Longitude=-6.153, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=3917, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=19, WindGust=32.0, Visibility=30000.0, ScreenTemperature=10.6, Pressure=1002.0, SignificantWeatherCode=8, SiteName='ALDERGROVE (3917)', Latitude=54.664, Longitude=-6.224, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=3923, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=36.0, Visibility=17000.0, ScreenTemperature=10.8, Pressure=1003.0, SignificantWeatherCode=7, SiteName='GLENANNE (3923)', Latitude=54.237, Longitude=-6.502, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=99018, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=15, WindGust=30.0, Visibility=None, ScreenTemperature=-99.0, Pressure=None, SignificantWeatherCode=-99, SiteName='ORLOCK HEAD (99018)', Latitude=54.67, Longitude=-5.58, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=3305, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=34, WindGust=54.0, Visibility=12000.0, ScreenTemperature=11.1, Pressure=1008.0, SignificantWeatherCode=8, SiteName='CAPEL CURIG SAWS (3305)', Latitude=53.093, Longitude=-3.941, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3313, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=23, WindGust=34.0, Visibility=40000.0, ScreenTemperature=12.7, Pressure=1007.0, SignificantWeatherCode=7, SiteName='RHYL (3313)', Latitude=53.259, Longitude=-3.509, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3321, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=16, WindGust=28.0, Visibility=35000.0, ScreenTemperature=12.9, Pressure=1008.0, SignificantWeatherCode=7, SiteName='HAWARDEN (3321)', Latitude=53.174, Longitude=-2.986, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3405, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=9, WindSpeed=32, WindGust=56.0, Visibility=10000.0, ScreenTemperature=10.4, Pressure=1011.0, SignificantWeatherCode=8, SiteName='ABERDARON (3405)', Latitude=52.789, Longitude=-4.742, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3409, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=13, WindGust=None, Visibility=None, ScreenTemperature=10.7, Pressure=1010.0, SignificantWeatherCode=-99, SiteName='BALA (3409)', Latitude=52.92, Longitude=-3.58, Region='Wales', Country=None),
#   Row(ForecastSiteCode=3410, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=21, WindGust=37.0, Visibility=25000.0, ScreenTemperature=10.4, Pressure=1009.0, SignificantWeatherCode=8, SiteName='LAKE VYRNWY SAWS (3410)', Latitude=52.757, Longitude=-3.464, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3503, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=16, WindGust=34.0, Visibility=8000.0, ScreenTemperature=11.6, Pressure=1013.0, SignificantWeatherCode=8, SiteName='TRAWSGOED (3503)', Latitude=52.344, Longitude=-3.947, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3507, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=21, WindGust=31.0, Visibility=10000.0, ScreenTemperature=9.7, Pressure=1013.0, SignificantWeatherCode=8, SiteName='SENNYBRIDGE (3507)', Latitude=52.063, Longitude=-3.614, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3605, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=28, WindGust=33.0, Visibility=4500.0, ScreenTemperature=10.9, Pressure=1015.0, SignificantWeatherCode=8, SiteName='PEMBREY SANDS SAMOS (3605)', Latitude=51.713, Longitude=-4.368, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3716, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=23, WindGust=38.0, Visibility=16000.0, ScreenTemperature=10.7, Pressure=1015.0, SignificantWeatherCode=8, SiteName='ST-ATHAN (3716)', Latitude=51.405, Longitude=-3.44, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3214, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=24, WindGust=34.0, Visibility=10000.0, ScreenTemperature=10.0, Pressure=1005.0, SignificantWeatherCode=8, SiteName='WALNEY ISLAND (3214)', Latitude=54.125, Longitude=-3.257, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3220, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=16, WindSpeed=-99, WindGust=None, Visibility=25000.0, ScreenTemperature=11.1, Pressure=1002.0, SignificantWeatherCode=7, SiteName='CARLISLE (3220)', Latitude=54.933, Longitude=-2.963, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3318, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=24, WindGust=36.0, Visibility=None, ScreenTemperature=10.2, Pressure=None, SignificantWeatherCode=-99, SiteName='BLACKPOOL (3318)', Latitude=53.17, Longitude=-2.98, Region='North West England', Country=None),
#   Row(ForecastSiteCode=3230, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=13, WindGust=None, Visibility=3200.0, ScreenTemperature=9.0, Pressure=1001.0, SignificantWeatherCode=7, SiteName='REDESDALE CAMP (3230)', Latitude=55.28, Longitude=-2.28, Region='North East England', Country=None),
#   Row(ForecastSiteCode=3275, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=25, WindGust=38.0, Visibility=40000.0, ScreenTemperature=9.9, Pressure=1002.0, SignificantWeatherCode=2, SiteName='LOFTUS (3275)', Latitude=54.57, Longitude=-0.87, Region='North East England', Country=None),
#   Row(ForecastSiteCode=3257, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=23, WindGust=33.0, Visibility=28000.0, ScreenTemperature=12.0, Pressure=1003.0, SignificantWeatherCode=7, SiteName='LEEMING (3257)', Latitude=54.296, Longitude=-1.53, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3261, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=24, WindGust=38.0, Visibility=75000.0, ScreenTemperature=11.8, Pressure=1004.0, SignificantWeatherCode=7, SiteName='DISHFORTH AIRFIELD (3261)', Latitude=54.134, Longitude=-1.414, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3265, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=16, WindGust=29.0, Visibility=45000.0, ScreenTemperature=12.6, Pressure=1004.0, SignificantWeatherCode=8, SiteName='TOPCLIFFE (3265)', Latitude=54.204, Longitude=-1.39, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3266, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=15, WindGust=29.0, Visibility=35000.0, ScreenTemperature=12.1, Pressure=1004.0, SignificantWeatherCode=8, SiteName='LINTON ON OUSE (3266)', Latitude=54.045, Longitude=-1.25, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3281, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=14, WindGust=None, Visibility=None, ScreenTemperature=5.8, Pressure=None, SignificantWeatherCode=-99, SiteName='FYLINGDALES (3281)', Latitude=54.362, Longitude=-0.673, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3344, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=23, WindGust=45.0, Visibility=18000.0, ScreenTemperature=10.4, Pressure=1004.0, SignificantWeatherCode=12, SiteName='BINGLEY SAMOS (3344)', Latitude=53.811, Longitude=-1.865, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=99214, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=16, WindSpeed=-99, WindGust=None, Visibility=None, ScreenTemperature=11.6, Pressure=None, SignificantWeatherCode=-99, SiteName='HULL EAST (99214)', Latitude=53.76, Longitude=-0.29, Region='Yorkshire & Humber', Country=None),
#   Row(ForecastSiteCode=3414, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=29, WindGust=39.0, Visibility=16000.0, ScreenTemperature=12.0, Pressure=1009.0, SignificantWeatherCode=8, SiteName='SHAWBURY (3414)', Latitude=52.794, Longitude=-2.663, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3529, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=16, WindGust=30.0, Visibility=16000.0, ScreenTemperature=13.5, Pressure=1012.0, SignificantWeatherCode=8, SiteName='PERSHORE (3529)', Latitude=52.148, Longitude=-2.04, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3535, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=11, WindGust=None, Visibility=13000.0, ScreenTemperature=12.9, Pressure=1010.0, SignificantWeatherCode=8, SiteName='COLESHILL (3535)', Latitude=52.48, Longitude=-1.689, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3544, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=13, WindGust=26.0, Visibility=11000.0, ScreenTemperature=12.2, Pressure=1010.0, SignificantWeatherCode=8, SiteName='CHURCH LAWFORD (3544)', Latitude=52.358, Longitude=-1.33, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3373, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=29.0, Visibility=35000.0, ScreenTemperature=11.6, Pressure=1006.0, SignificantWeatherCode=8, SiteName='SCAMPTON (3373)', Latitude=53.307, Longitude=-0.546, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3377, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=None, Visibility=25000.0, ScreenTemperature=11.7, Pressure=1007.0, SignificantWeatherCode=8, SiteName='WADDINGTON (3377)', Latitude=53.175, Longitude=-0.521, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3379, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=24, WindGust=36.0, Visibility=30000.0, ScreenTemperature=11.9, Pressure=1007.0, SignificantWeatherCode=8, SiteName='CRANWELL (3379)', Latitude=53.03, Longitude=-0.5, Region='East Midlands', Country=None),
#   Row(ForecastSiteCode=3385, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=9, WindSpeed=16, WindGust=None, Visibility=40000.0, ScreenTemperature=11.4, Pressure=1006.0, SignificantWeatherCode=8, SiteName='DONNA NOOK (3385)', Latitude=53.473, Longitude=0.154, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3391, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=29.0, Visibility=35000.0, ScreenTemperature=12.3, Pressure=1007.0, SignificantWeatherCode=8, SiteName='CONINGSBY (3391)', Latitude=53.094, Longitude=-0.171, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3392, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=None, Visibility=35000.0, ScreenTemperature=12.2, Pressure=1007.0, SignificantWeatherCode=8, SiteName='WAINFLEET (3392)', Latitude=53.088, Longitude=0.274, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3469, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=None, Visibility=35000.0, ScreenTemperature=12.7, Pressure=1008.0, SignificantWeatherCode=8, SiteName='HOLBEACH (3469)', Latitude=52.873, Longitude=0.141, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3462, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=32.0, Visibility=20000.0, ScreenTemperature=13.0, Pressure=1009.0, SignificantWeatherCode=8, SiteName='WITTERING (3462)', Latitude=52.611, Longitude=-0.459, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3482, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=None, Visibility=5000.0, ScreenTemperature=12.3, Pressure=1008.0, SignificantWeatherCode=8, SiteName='MARHAM (3482)', Latitude=52.651, Longitude=0.569, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3488, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=21, WindGust=33.0, Visibility=50000.0, ScreenTemperature=12.3, Pressure=1007.0, SignificantWeatherCode=8, SiteName='WEYBOURNE (3488)', Latitude=52.949, Longitude=1.127, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3560, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=14, WindGust=25.0, Visibility=11000.0, ScreenTemperature=11.7, Pressure=1010.0, SignificantWeatherCode=8, SiteName='BEDFORD (3560)', Latitude=52.225, Longitude=-0.464, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3647, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=21, WindGust=33.0, Visibility=11000.0, ScreenTemperature=10.6, Pressure=1012.0, SignificantWeatherCode=8, SiteName='LITTLE RISSINGTON (ESAWS) (3647)', Latitude=51.86, Longitude=-1.692, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3707, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=28, WindGust=36.0, Visibility=8000.0, ScreenTemperature=11.6, Pressure=1017.0, SignificantWeatherCode=8, SiteName='CHIVENOR (3707)', Latitude=51.089, Longitude=-4.149, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3710, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=19, WindGust=44.0, Visibility=9000.0, ScreenTemperature=8.6, Pressure=1017.0, SignificantWeatherCode=8, SiteName='LISCOMBE (3710)', Latitude=51.087, Longitude=-3.608, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3740, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=21, WindGust=37.0, Visibility=None, ScreenTemperature=10.5, Pressure=1015.0, SignificantWeatherCode=8, SiteName='LYNEHAM (3740)', Latitude=51.5031, Longitude=-1.9924, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3746, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=16, WindGust=None, Visibility=13000.0, ScreenTemperature=11.1, Pressure=1015.0, SignificantWeatherCode=8, SiteName='BOSCOMBE DOWN (3746)', Latitude=51.161, Longitude=-1.754, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3803, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=23, WindGust=33.0, Visibility=8000.0, ScreenTemperature=11.8, Pressure=1020.0, SignificantWeatherCode=-99, SiteName='SCILLY ST MARYS (3803)', Latitude=49.913, Longitude=-6.301, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3808, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=24, WindGust=34.0, Visibility=12000.0, ScreenTemperature=11.7, Pressure=1020.0, SignificantWeatherCode=8, SiteName='CAMBORNE (3808)', Latitude=50.218, Longitude=-5.33, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3809, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=13, WindGust=31.0, Visibility=7000.0, ScreenTemperature=11.3, Pressure=1020.0, SignificantWeatherCode=8, SiteName='CULDROSE (3809)', Latitude=50.085, Longitude=-5.257, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3827, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=18, WindGust=31.0, Visibility=7000.0, ScreenTemperature=11.5, Pressure=1019.0, SignificantWeatherCode=8, SiteName='MOUNT BATTEN (3827)', Latitude=50.354, Longitude=-4.121, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3857, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=22, WindGust=38.0, Visibility=6000.0, ScreenTemperature=11.0, Pressure=1018.0, SignificantWeatherCode=8, SiteName='ISLE OF PORTLAND (3857)', Latitude=50.522, Longitude=-2.454, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3749, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=31.0, Visibility=19000.0, ScreenTemperature=11.5, Pressure=1015.0, SignificantWeatherCode=8, SiteName='MIDDLE WALLOP (3749)', Latitude=51.15, Longitude=-1.57, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3761, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=25, WindGust=43.0, Visibility=18000.0, ScreenTemperature=11.8, Pressure=1014.0, SignificantWeatherCode=8, SiteName='ODIHAM (3761)', Latitude=51.238, Longitude=-0.944, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3768, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=32.0, Visibility=20000.0, ScreenTemperature=12.3, Pressure=1014.0, SignificantWeatherCode=8, SiteName='FARNBOROUGH (3768)', Latitude=51.279, Longitude=-0.772, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3772, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=14, WindGust=None, Visibility=10000.0, ScreenTemperature=12.3, Pressure=1013.0, SignificantWeatherCode=8, SiteName='HEATHROW (3772)', Latitude=51.479, Longitude=-0.449, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3781, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=33.0, Visibility=15000.0, ScreenTemperature=11.5, Pressure=1013.0, SignificantWeatherCode=8, SiteName='KENLEY (3781)', Latitude=51.303, Longitude=-0.09, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3784, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=32.0, Visibility=None, ScreenTemperature=12.7, Pressure=1012.0, SignificantWeatherCode=-99, SiteName='GRAVESEND-BROADNESS (3784)', Latitude=51.464, Longitude=0.314, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3797, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=16, WindGust=30.0, Visibility=40000.0, ScreenTemperature=12.3, Pressure=1013.0, SignificantWeatherCode=7, SiteName='MANSTON (3797)', Latitude=51.3422, Longitude=1.3461, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3866, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=29, WindGust=36.0, Visibility=None, ScreenTemperature=10.7, Pressure=1017.0, SignificantWeatherCode=-99, SiteName='ST CATHERINES PT. (3866)', Latitude=50.577, Longitude=-1.297, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3876, ObservationTime=0, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=None, Visibility=None, ScreenTemperature=11.0, Pressure=1016.0, SignificantWeatherCode=-99, SiteName='SHOREHAM (3876)', Latitude=50.836, Longitude=-0.292, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3002, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=8, WindGust=None, Visibility=30000.0, ScreenTemperature=1.2, Pressure=996.0, SignificantWeatherCode=8, SiteName='BALTASOUND (3002)', Latitude=60.749, Longitude=-0.854, Region='Orkney & Shetland', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3005, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=8, WindSpeed=5, WindGust=None, Visibility=35000.0, ScreenTemperature=0.6, Pressure=996.0, SignificantWeatherCode=7, SiteName='LERWICK (S. SCREEN) (3005)', Latitude=60.139, Longitude=-1.183, Region='Orkney & Shetland', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3008, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=6, WindSpeed=11, WindGust=None, Visibility=50000.0, ScreenTemperature=3.9, Pressure=996.0, SignificantWeatherCode=-99, SiteName='FAIR ISLE (3008)', Latitude=59.53, Longitude=-1.63, Region='Orkney & Shetland', Country=None),
#   Row(ForecastSiteCode=3026, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=6, WindSpeed=15, WindGust=None, Visibility=10000.0, ScreenTemperature=5.1, Pressure=989.0, SignificantWeatherCode=12, SiteName='STORNOWAY (3026)', Latitude=58.214, Longitude=-6.325, Region='Highland & Eilean Siar', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3034, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=8, WindSpeed=18, WindGust=None, Visibility=8000.0, ScreenTemperature=8.1, Pressure=991.0, SignificantWeatherCode=15, SiteName='AULTBEA (3034)', Latitude=57.859, Longitude=-5.636, Region='Highland & Eilean Siar', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3039, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=31, WindGust=41.0, Visibility=None, ScreenTemperature=5.5, Pressure=None, SignificantWeatherCode=-99, SiteName='BEALACH NA BA (3039)', Latitude=57.42, Longitude=-5.69, Region='Highland & Eilean Siar', Country=None),
#   Row(ForecastSiteCode=3041, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=41, WindGust=82.0, Visibility=None, ScreenTemperature=3.9, Pressure=None, SignificantWeatherCode=-99, SiteName='AONACH MOR (3041)', Latitude=56.82, Longitude=-4.97, Region='Highland & Eilean Siar', Country=None),
#   Row(ForecastSiteCode=3044, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=15, WindSpeed=7, WindGust=None, Visibility=5000.0, ScreenTemperature=1.9, Pressure=993.0, SignificantWeatherCode=9, SiteName='ALTNAHARRA SAWS (3044)', Latitude=58.288, Longitude=-4.442, Region='Highland & Eilean Siar', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3065, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=54, WindGust=89.0, Visibility=None, ScreenTemperature=3.1, Pressure=None, SignificantWeatherCode=-99, SiteName='CAIRNGORM SUMMIT (3065)', Latitude=57.12, Longitude=-3.64, Region='Grampian', Country=None),
#   Row(ForecastSiteCode=3088, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=8, WindSpeed=16, WindGust=None, Visibility=100.0, ScreenTemperature=4.8, Pressure=997.0, SignificantWeatherCode=9, SiteName='INVERBERVIE (3088)', Latitude=56.85, Longitude=-2.27, Region='Grampian', Country=None),
#   Row(ForecastSiteCode=3105, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=28, WindGust=37.0, Visibility=12000.0, ScreenTemperature=10.5, Pressure=1000.0, SignificantWeatherCode=7, SiteName='ISLAY/PORT ELLEN (3105)', Latitude=55.681, Longitude=-6.256, Region='Strathclyde', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3111, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=22, WindGust=37.0, Visibility=20000.0, ScreenTemperature=11.5, Pressure=1000.0, SignificantWeatherCode=8, SiteName='MACHRIHANISH (3111)', Latitude=55.441, Longitude=-5.699, Region='Strathclyde', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3136, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=17, WindGust=31.0, Visibility=4500.0, ScreenTemperature=10.1, Pressure=1001.0, SignificantWeatherCode=8, SiteName='PRESTWICK RNAS (3136)', Latitude=55.515, Longitude=-4.585, Region='Strathclyde', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3155, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=26, WindGust=37.0, Visibility=6000.0, ScreenTemperature=9.4, Pressure=1000.0, SignificantWeatherCode=8, SiteName='DRUMALBIN (3155)', Latitude=55.627, Longitude=-3.735, Region='Strathclyde', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3153, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=34, WindGust=45.0, Visibility=6000.0, ScreenTemperature=9.6, Pressure=1002.0, SignificantWeatherCode=5, SiteName='DUNDRENNAN (3153)', Latitude=54.803, Longitude=-4.008, Region='Dumfries, Galloway', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3166, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=10, WindGust=None, Visibility=15000.0, ScreenTemperature=9.5, Pressure=998.0, SignificantWeatherCode=11, SiteName='EDINBURGH/GOGARBANK (3166)', Latitude=55.928, Longitude=-3.343, Region='Dumfries, Galloway', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3917, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=16, WindGust=32.0, Visibility=4800.0, ScreenTemperature=10.4, Pressure=1003.0, SignificantWeatherCode=12, SiteName='ALDERGROVE (3917)', Latitude=54.664, Longitude=-6.224, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=3923, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=19, WindGust=38.0, Visibility=17000.0, ScreenTemperature=10.4, Pressure=1003.0, SignificantWeatherCode=8, SiteName='GLENANNE (3923)', Latitude=54.237, Longitude=-6.502, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=99018, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=36.0, Visibility=None, ScreenTemperature=-99.0, Pressure=None, SignificantWeatherCode=-99, SiteName='ORLOCK HEAD (99018)', Latitude=54.67, Longitude=-5.58, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=3305, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=39, WindGust=52.0, Visibility=4900.0, ScreenTemperature=10.7, Pressure=1009.0, SignificantWeatherCode=7, SiteName='CAPEL CURIG SAWS (3305)', Latitude=53.093, Longitude=-3.941, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3405, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=9, WindSpeed=34, WindGust=51.0, Visibility=11000.0, ScreenTemperature=10.4, Pressure=1011.0, SignificantWeatherCode=8, SiteName='ABERDARON (3405)', Latitude=52.789, Longitude=-4.742, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3409, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=14, WindGust=None, Visibility=None, ScreenTemperature=10.1, Pressure=1011.0, SignificantWeatherCode=-99, SiteName='BALA (3409)', Latitude=52.92, Longitude=-3.58, Region='Wales', Country=None),
#   Row(ForecastSiteCode=3502, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=32, WindGust=45.0, Visibility=6000.0, ScreenTemperature=10.6, Pressure=1014.0, SignificantWeatherCode=8, SiteName='ABERPORTH (3502)', Latitude=52.139, Longitude=-4.571, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3503, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=31.0, Visibility=13000.0, ScreenTemperature=12.0, Pressure=1013.0, SignificantWeatherCode=7, SiteName='TRAWSGOED (3503)', Latitude=52.344, Longitude=-3.947, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3605, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=29, WindGust=36.0, Visibility=4300.0, ScreenTemperature=10.7, Pressure=1016.0, SignificantWeatherCode=8, SiteName='PEMBREY SANDS SAMOS (3605)', Latitude=51.713, Longitude=-4.368, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3716, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=24, WindGust=34.0, Visibility=12000.0, ScreenTemperature=10.8, Pressure=1016.0, SignificantWeatherCode=8, SiteName='ST-ATHAN (3716)', Latitude=51.405, Longitude=-3.44, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3210, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=9, WindSpeed=16, WindGust=None, Visibility=7000.0, ScreenTemperature=9.1, Pressure=1005.0, SignificantWeatherCode=7, SiteName='ST. BEES HEAD (3210)', Latitude=54.518, Longitude=-3.615, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3212, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=11, WindGust=30.0, Visibility=7000.0, ScreenTemperature=11.7, Pressure=1004.0, SignificantWeatherCode=11, SiteName='KESWICK (3212)', Latitude=54.614, Longitude=-3.157, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3220, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=16, WindSpeed=-99, WindGust=None, Visibility=15000.0, ScreenTemperature=11.2, Pressure=1003.0, SignificantWeatherCode=8, SiteName='CARLISLE (3220)', Latitude=54.933, Longitude=-2.963, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3225, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=32.0, Visibility=16000.0, ScreenTemperature=10.5, Pressure=1004.0, SignificantWeatherCode=8, SiteName='SHAP (3225)', Latitude=54.501, Longitude=-2.684, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3227, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=47, WindGust=55.0, Visibility=None, ScreenTemperature=9.5, Pressure=None, SignificantWeatherCode=-99, SiteName='GREAT DUN FELL (3227)', Latitude=54.68, Longitude=-2.45, Region='North West England', Country=None),
#   Row(ForecastSiteCode=3230, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=31.0, Visibility=5000.0, ScreenTemperature=9.6, Pressure=1001.0, SignificantWeatherCode=8, SiteName='REDESDALE CAMP (3230)', Latitude=55.28, Longitude=-2.28, Region='North East England', Country=None),
#   Row(ForecastSiteCode=3238, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=22, WindGust=38.0, Visibility=13000.0, ScreenTemperature=10.8, Pressure=1000.0, SignificantWeatherCode=8, SiteName='ALBEMARLE (3238)', Latitude=55.02, Longitude=-1.88, Region='North East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3240, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=6, WindSpeed=10, WindGust=None, Visibility=None, ScreenTemperature=6.1, Pressure=1000.0, SignificantWeatherCode=8, SiteName='BOULMER (3240)', Latitude=55.421, Longitude=-1.6, Region='North East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3275, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=26, WindGust=37.0, Visibility=45000.0, ScreenTemperature=10.1, Pressure=1002.0, SignificantWeatherCode=0, SiteName='LOFTUS (3275)', Latitude=54.57, Longitude=-0.87, Region='North East England', Country=None),
#   Row(ForecastSiteCode=3257, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=26, WindGust=47.0, Visibility=26000.0, ScreenTemperature=12.1, Pressure=1003.0, SignificantWeatherCode=2, SiteName='LEEMING (3257)', Latitude=54.296, Longitude=-1.53, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3261, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=29, WindGust=39.0, Visibility=50000.0, ScreenTemperature=11.9, Pressure=1005.0, SignificantWeatherCode=8, SiteName='DISHFORTH AIRFIELD (3261)', Latitude=54.134, Longitude=-1.414, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3266, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=31, WindGust=45.0, Visibility=22000.0, ScreenTemperature=11.9, Pressure=1004.0, SignificantWeatherCode=8, SiteName='LINTON ON OUSE (3266)', Latitude=54.045, Longitude=-1.25, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=99214, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=16, WindSpeed=-99, WindGust=None, Visibility=None, ScreenTemperature=12.2, Pressure=None, SignificantWeatherCode=-99, SiteName='HULL EAST (99214)', Latitude=53.76, Longitude=-0.29, Region='Yorkshire & Humber', Country=None),
#   Row(ForecastSiteCode=3520, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=17, WindGust=None, Visibility=23000.0, ScreenTemperature=11.7, Pressure=1012.0, SignificantWeatherCode=2, SiteName='SHOBDON SAWS (3520)', Latitude=52.242, Longitude=-2.885, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3522, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=10, WindGust=22.0, Visibility=19000.0, ScreenTemperature=12.8, Pressure=1013.0, SignificantWeatherCode=8, SiteName='HEREFORD (3522)', Latitude=52.083, Longitude=-2.8, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3529, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=14, WindGust=31.0, Visibility=21000.0, ScreenTemperature=13.3, Pressure=1012.0, SignificantWeatherCode=8, SiteName='PERSHORE (3529)', Latitude=52.148, Longitude=-2.04, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3535, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=9, WindGust=None, Visibility=18000.0, ScreenTemperature=12.8, Pressure=1010.0, SignificantWeatherCode=8, SiteName='COLESHILL (3535)', Latitude=52.48, Longitude=-1.689, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3354, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=16, WindGust=29.0, Visibility=30000.0, ScreenTemperature=12.1, Pressure=1008.0, SignificantWeatherCode=7, SiteName='WATNALL (3354)', Latitude=53.005, Longitude=-1.25, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3391, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=22, WindGust=30.0, Visibility=35000.0, ScreenTemperature=12.6, Pressure=1008.0, SignificantWeatherCode=8, SiteName='CONINGSBY (3391)', Latitude=53.094, Longitude=-0.171, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3392, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=None, Visibility=25000.0, ScreenTemperature=12.4, Pressure=1008.0, SignificantWeatherCode=8, SiteName='WAINFLEET (3392)', Latitude=53.088, Longitude=0.274, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3469, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=21, WindGust=None, Visibility=45000.0, ScreenTemperature=12.8, Pressure=1009.0, SignificantWeatherCode=8, SiteName='HOLBEACH (3469)', Latitude=52.873, Longitude=0.141, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3462, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=17, WindGust=None, Visibility=20000.0, ScreenTemperature=12.6, Pressure=1009.0, SignificantWeatherCode=8, SiteName='WITTERING (3462)', Latitude=52.611, Longitude=-0.459, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3488, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=23, WindGust=33.0, Visibility=12000.0, ScreenTemperature=12.3, Pressure=1008.0, SignificantWeatherCode=8, SiteName='WEYBOURNE (3488)', Latitude=52.949, Longitude=1.127, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3590, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=29.0, Visibility=12000.0, ScreenTemperature=11.9, Pressure=1011.0, SignificantWeatherCode=7, SiteName='WATTISHAM (3590)', Latitude=52.123, Longitude=0.961, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3684, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=23, WindGust=34.0, Visibility=17000.0, ScreenTemperature=11.9, Pressure=1012.0, SignificantWeatherCode=8, SiteName='ANDREWS FIELD (3684)', Latitude=51.896, Longitude=0.453, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3647, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=36.0, Visibility=13000.0, ScreenTemperature=10.5, Pressure=1012.0, SignificantWeatherCode=8, SiteName='LITTLE RISSINGTON (ESAWS) (3647)', Latitude=51.86, Longitude=-1.692, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3707, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=26, WindGust=38.0, Visibility=7000.0, ScreenTemperature=11.6, Pressure=1018.0, SignificantWeatherCode=7, SiteName='CHIVENOR (3707)', Latitude=51.089, Longitude=-4.149, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3710, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=15, WindGust=43.0, Visibility=7000.0, ScreenTemperature=8.7, Pressure=1017.0, SignificantWeatherCode=8, SiteName='LISCOMBE (3710)', Latitude=51.087, Longitude=-3.608, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3803, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=24, WindGust=33.0, Visibility=8000.0, ScreenTemperature=11.6, Pressure=1020.0, SignificantWeatherCode=-99, SiteName='SCILLY ST MARYS (3803)', Latitude=49.913, Longitude=-6.301, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3808, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=21, WindGust=32.0, Visibility=10000.0, ScreenTemperature=11.2, Pressure=1020.0, SignificantWeatherCode=8, SiteName='CAMBORNE (3808)', Latitude=50.218, Longitude=-5.33, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3809, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=15, WindGust=29.0, Visibility=6000.0, ScreenTemperature=11.0, Pressure=1020.0, SignificantWeatherCode=8, SiteName='CULDROSE (3809)', Latitude=50.085, Longitude=-5.257, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3823, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=19, WindGust=37.0, Visibility=9000.0, ScreenTemperature=10.2, Pressure=1019.0, SignificantWeatherCode=7, SiteName='CARDINHAM (3823)', Latitude=50.502, Longitude=-4.667, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3840, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=16, WindGust=None, Visibility=8000.0, ScreenTemperature=10.0, Pressure=1018.0, SignificantWeatherCode=7, SiteName='DUNKESWELL AERODROME (3840)', Latitude=50.86, Longitude=-3.239, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3853, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=34.0, Visibility=13000.0, ScreenTemperature=12.0, Pressure=1017.0, SignificantWeatherCode=8, SiteName='YEOVILTON (3853)', Latitude=51.006, Longitude=-2.64, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3649, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=13, WindGust=26.0, Visibility=12000.0, ScreenTemperature=11.1, Pressure=1013.0, SignificantWeatherCode=8, SiteName='BRIZE NORTON (3649)', Latitude=51.758, Longitude=-1.576, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3658, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=14, WindGust=30.0, Visibility=14000.0, ScreenTemperature=11.7, Pressure=1014.0, SignificantWeatherCode=8, SiteName='BENSON (3658)', Latitude=51.62, Longitude=-1.097, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3660, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=11, WindGust=31.0, Visibility=7000.0, ScreenTemperature=10.5, Pressure=1013.0, SignificantWeatherCode=8, SiteName='HIGH WYCOMBE (3660)', Latitude=51.68, Longitude=-0.802, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3772, ObservationTime=1, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=31.0, Visibility=11000.0, ScreenTemperature=12.3, Pressure=1014.0, SignificantWeatherCode=8, SiteName='HEATHROW (3772)', Latitude=51.479, Longitude=-0.449, Region='London & South East England', Country='ENGLAND'),
# ...
#   Row(ForecastSiteCode=3080, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=29, WindGust=47.0, Visibility=17000.0, ScreenTemperature=7.1, Pressure=988.0, SignificantWeatherCode=7, SiteName='ABOYNE (3080)', Latitude=57.077, Longitude=-2.836, Region='Grampian', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3088, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=43, WindGust=60.0, Visibility=21000.0, ScreenTemperature=6.2, Pressure=988.0, SignificantWeatherCode=1, SiteName='INVERBERVIE (3088)', Latitude=56.85, Longitude=-2.27, Region='Grampian', Country=None),
#   Row(ForecastSiteCode=3134, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=26, WindGust=49.0, Visibility=16000.0, ScreenTemperature=7.3, Pressure=994.0, SignificantWeatherCode=8, SiteName='GLASGOW/BISHOPTON (3134)', Latitude=55.907, Longitude=-4.533, Region='Strathclyde', Country='ENGLAND'),
#   Row(ForecastSiteCode=3144, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=23, WindGust=44.0, Visibility=20000.0, ScreenTemperature=6.7, Pressure=991.0, SignificantWeatherCode=3, SiteName='STRATHALLAN (3144)', Latitude=56.326, Longitude=-3.729, Region='Central Tayside & Fife', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3132, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=30, WindGust=54.0, Visibility=17000.0, ScreenTemperature=9.2, Pressure=999.0, SignificantWeatherCode=3, SiteName='WEST FREUGH (ESAWS) (3132)', Latitude=54.859, Longitude=-4.936, Region='Dumfries, Galloway', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3153, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=29, WindGust=51.0, Visibility=14000.0, ScreenTemperature=9.3, Pressure=999.0, SignificantWeatherCode=7, SiteName='DUNDRENNAN (3153)', Latitude=54.803, Longitude=-4.008, Region='Dumfries, Galloway', Country='SCOTLAND'),
#   Row(ForecastSiteCode=3915, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=21, WindGust=51.0, Visibility=15000.0, ScreenTemperature=8.2, Pressure=999.0, SignificantWeatherCode=8, SiteName='PORTGLENONE (3915)', Latitude=54.87, Longitude=-6.45, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=3923, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=21, WindGust=41.0, Visibility=13000.0, ScreenTemperature=8.2, Pressure=1001.0, SignificantWeatherCode=7, SiteName='GLENANNE (3923)', Latitude=54.237, Longitude=-6.502, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=99018, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=45, WindGust=75.0, Visibility=None, ScreenTemperature=-99.0, Pressure=None, SignificantWeatherCode=-99, SiteName='ORLOCK HEAD (99018)', Latitude=54.67, Longitude=-5.58, Region='Northern Ireland', Country='NORTHERN IRELAND'),
#   Row(ForecastSiteCode=3313, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=43.0, Visibility=17000.0, ScreenTemperature=11.0, Pressure=1006.0, SignificantWeatherCode=1, SiteName='RHYL (3313)', Latitude=53.259, Longitude=-3.509, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3405, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=9, WindSpeed=34, WindGust=52.0, Visibility=16000.0, ScreenTemperature=10.6, Pressure=1009.0, SignificantWeatherCode=8, SiteName='ABERDARON (3405)', Latitude=52.789, Longitude=-4.742, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3410, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=48, WindGust=68.0, Visibility=14000.0, ScreenTemperature=8.7, Pressure=1008.0, SignificantWeatherCode=8, SiteName='LAKE VYRNWY SAWS (3410)', Latitude=52.757, Longitude=-3.464, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3502, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=39, WindGust=56.0, Visibility=12000.0, ScreenTemperature=10.8, Pressure=1012.0, SignificantWeatherCode=7, SiteName='ABERPORTH (3502)', Latitude=52.139, Longitude=-4.571, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3605, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=36, WindGust=44.0, Visibility=6000.0, ScreenTemperature=11.4, Pressure=1014.0, SignificantWeatherCode=8, SiteName='PEMBREY SANDS SAMOS (3605)', Latitude=51.713, Longitude=-4.368, Region='Wales', Country='WALES'),
#   Row(ForecastSiteCode=3204, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=40, WindGust=57.0, Visibility=15000.0, ScreenTemperature=10.3, Pressure=1003.0, SignificantWeatherCode=3, SiteName='RONALDSWAY (3204)', Latitude=54.0849, Longitude=-4.6321, Region='North West England', Country='ISLE OF MAN'),
#   Row(ForecastSiteCode=3210, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=33, WindGust=53.0, Visibility=15000.0, ScreenTemperature=8.8, Pressure=1002.0, SignificantWeatherCode=7, SiteName='ST. BEES HEAD (3210)', Latitude=54.518, Longitude=-3.615, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3212, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=19, WindGust=39.0, Visibility=13000.0, ScreenTemperature=9.5, Pressure=1002.0, SignificantWeatherCode=8, SiteName='KESWICK (3212)', Latitude=54.614, Longitude=-3.157, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3214, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=30, WindGust=47.0, Visibility=10000.0, ScreenTemperature=9.9, Pressure=1004.0, SignificantWeatherCode=7, SiteName='WALNEY ISLAND (3214)', Latitude=54.125, Longitude=-3.257, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3224, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=41, WindGust=60.0, Visibility=16000.0, ScreenTemperature=7.0, Pressure=999.0, SignificantWeatherCode=7, SiteName='SPADEADAM (3224)', Latitude=55.05, Longitude=-2.553, Region='North West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3227, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=63, WindGust=84.0, Visibility=None, ScreenTemperature=6.9, Pressure=None, SignificantWeatherCode=-99, SiteName='GREAT DUN FELL (3227)', Latitude=54.68, Longitude=-2.45, Region='North West England', Country=None),
#   Row(ForecastSiteCode=3238, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=23, WindGust=44.0, Visibility=14000.0, ScreenTemperature=9.5, Pressure=997.0, SignificantWeatherCode=1, SiteName='ALBEMARLE (3238)', Latitude=55.02, Longitude=-1.88, Region='North East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3275, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=39, WindGust=61.0, Visibility=4600.0, ScreenTemperature=9.1, Pressure=1000.0, SignificantWeatherCode=7, SiteName='LOFTUS (3275)', Latitude=54.57, Longitude=-0.87, Region='North East England', Country=None),
#   Row(ForecastSiteCode=3261, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=24, WindGust=54.0, Visibility=23000.0, ScreenTemperature=11.6, Pressure=1002.0, SignificantWeatherCode=7, SiteName='DISHFORTH AIRFIELD (3261)', Latitude=54.134, Longitude=-1.414, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3266, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=36, WindGust=57.0, Visibility=20000.0, ScreenTemperature=12.0, Pressure=1003.0, SignificantWeatherCode=3, SiteName='LINTON ON OUSE (3266)', Latitude=54.045, Longitude=-1.25, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3344, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=24, WindGust=52.0, Visibility=13000.0, ScreenTemperature=9.6, Pressure=1004.0, SignificantWeatherCode=7, SiteName='BINGLEY SAMOS (3344)', Latitude=53.811, Longitude=-1.865, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3382, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=31, WindGust=52.0, Visibility=24000.0, ScreenTemperature=12.6, Pressure=1003.0, SignificantWeatherCode=3, SiteName='LECONFIELD SAR (3382)', Latitude=53.867, Longitude=-0.433, Region='Yorkshire & Humber', Country='ENGLAND'),
#   Row(ForecastSiteCode=3330, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=29, WindGust=48.0, Visibility=12000.0, ScreenTemperature=10.6, Pressure=1007.0, SignificantWeatherCode=7, SiteName='LEEK (3330)', Latitude=53.133, Longitude=-1.983, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3414, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=38, WindGust=57.0, Visibility=20000.0, ScreenTemperature=12.2, Pressure=1007.0, SignificantWeatherCode=7, SiteName='SHAWBURY (3414)', Latitude=52.794, Longitude=-2.663, Region='West Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3379, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=41, WindGust=57.0, Visibility=45000.0, ScreenTemperature=13.5, Pressure=1006.0, SignificantWeatherCode=7, SiteName='CRANWELL (3379)', Latitude=53.03, Longitude=-0.5, Region='East Midlands', Country=None),
#   Row(ForecastSiteCode=3385, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=26, WindGust=45.0, Visibility=30000.0, ScreenTemperature=14.6, Pressure=1004.0, SignificantWeatherCode=3, SiteName='DONNA NOOK (3385)', Latitude=53.473, Longitude=0.154, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3392, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=31, WindGust=44.0, Visibility=30000.0, ScreenTemperature=13.9, Pressure=1006.0, SignificantWeatherCode=8, SiteName='WAINFLEET (3392)', Latitude=53.088, Longitude=0.274, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3469, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=25, WindGust=43.0, Visibility=35000.0, ScreenTemperature=12.7, Pressure=1008.0, SignificantWeatherCode=10, SiteName='HOLBEACH (3469)', Latitude=52.873, Longitude=0.141, Region='East Midlands', Country='ENGLAND'),
#   Row(ForecastSiteCode=3462, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=29, WindGust=48.0, Visibility=55000.0, ScreenTemperature=13.2, Pressure=1007.0, SignificantWeatherCode=1, SiteName='WITTERING (3462)', Latitude=52.611, Longitude=-0.459, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3482, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=26, WindGust=38.0, Visibility=20000.0, ScreenTemperature=13.0, Pressure=1009.0, SignificantWeatherCode=7, SiteName='MARHAM (3482)', Latitude=52.651, Longitude=0.569, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3488, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=30, WindGust=43.0, Visibility=50000.0, ScreenTemperature=13.5, Pressure=1007.0, SignificantWeatherCode=7, SiteName='WEYBOURNE (3488)', Latitude=52.949, Longitude=1.127, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3560, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=23, WindGust=45.0, Visibility=35000.0, ScreenTemperature=13.2, Pressure=1010.0, SignificantWeatherCode=7, SiteName='BEDFORD (3560)', Latitude=52.225, Longitude=-0.464, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3693, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=18, WindGust=33.0, Visibility=28000.0, ScreenTemperature=12.7, Pressure=1014.0, SignificantWeatherCode=7, SiteName='SHOEBURYNESS (3693)', Latitude=51.554, Longitude=0.83, Region='East of England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3808, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=12, WindSpeed=22, WindGust=34.0, Visibility=7000.0, ScreenTemperature=12.3, Pressure=1019.0, SignificantWeatherCode=7, SiteName='CAMBORNE (3808)', Latitude=50.218, Longitude=-5.33, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3827, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=29, WindGust=39.0, Visibility=5000.0, ScreenTemperature=11.3, Pressure=1019.0, SignificantWeatherCode=11, SiteName='MOUNT BATTEN (3827)', Latitude=50.354, Longitude=-4.121, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3840, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=24, WindGust=39.0, Visibility=12000.0, ScreenTemperature=11.7, Pressure=1017.0, SignificantWeatherCode=7, SiteName='DUNKESWELL AERODROME (3840)', Latitude=50.86, Longitude=-3.239, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3857, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=38, WindGust=49.0, Visibility=5000.0, ScreenTemperature=11.2, Pressure=1018.0, SignificantWeatherCode=5, SiteName='ISLE OF PORTLAND (3857)', Latitude=50.522, Longitude=-2.454, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3862, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=24, WindGust=39.0, Visibility=16000.0, ScreenTemperature=12.8, Pressure=1017.0, SignificantWeatherCode=8, SiteName='HURN (3862)', Latitude=50.779, Longitude=-1.835, Region='South West England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3649, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=11, WindSpeed=22, WindGust=47.0, Visibility=15000.0, ScreenTemperature=12.9, Pressure=1012.0, SignificantWeatherCode=7, SiteName='BRIZE NORTON (3649)', Latitude=51.758, Longitude=-1.576, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3658, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=21, WindGust=39.0, Visibility=20000.0, ScreenTemperature=13.1, Pressure=1013.0, SignificantWeatherCode=12, SiteName='BENSON (3658)', Latitude=51.62, Longitude=-1.097, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3761, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=26, WindGust=43.0, Visibility=20000.0, ScreenTemperature=12.0, Pressure=1015.0, SignificantWeatherCode=12, SiteName='ODIHAM (3761)', Latitude=51.238, Longitude=-0.944, Region='London & South East England', Country='ENGLAND'),
#   Row(ForecastSiteCode=3768, ObservationTime=14, ObservationDate=datetime.datetime(2016, 2, 1, 5, 0), WindDirection=10, WindSpeed=19, WindGust=33.0, Visibility=27000.0, ScreenTemperature=12.7, Pressure=1015.0, SignificantWeatherCode=8, SiteName='FARNBOROUGH (3768)', Latitude=51.279, Longitude=-0.772, Region='London & South East England', Country='ENGLAND'),
#   ...]]

# %%
schema = ['sid','sname','did']
data = [('s1','ali',1),('s2','b',1),('s3','c',2),('s4','d',3),('s5','e',2),]

# %%
stdDF_1 = spark.createDataFrame(data,schema)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-89807e70d201> in <module>
# ----> 1 stdDF_1 = spark.createDataFrame(data,schema)
#
# C:\spark\python\pyspark\sql\session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     746             rdd, schema = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#     747         else:
# --> 748             rdd, schema = self._createFromLocal(map(prepare, data), schema)
#     749         jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#     750         jdf = self._jsparkSession.applySchemaToPythonRDD(jrdd.rdd(), schema.json())
#
# C:\spark\python\pyspark\sql\session.py in _createFromLocal(self, data, schema)
#     414
#     415         if schema is None or isinstance(schema, (list, tuple)):
# --> 416             struct = self._inferSchemaFromList(data, names=schema)
#     417             converter = _create_converter(struct)
#     418             data = map(converter, data)
#
# C:\spark\python\pyspark\sql\session.py in _inferSchemaFromList(self, data, names)
#     346             warnings.warn("inferring schema from dict is deprecated,"
#     347                           "please use pyspark.sql.Row instead")
# --> 348         schema = reduce(_merge_type, (_infer_schema(row, names) for row in data))
#     349         if _has_nulltype(schema):
#     350             raise ValueError("Some of types cannot be determined after inferring")
#
# C:\spark\python\pyspark\sql\types.py in _merge_type(a, b, name)
#    1099         fields = [StructField(f.name, _merge_type(f.dataType, nfs.get(f.name, NullType()),
#    1100                                                   name=new_name(f.name)))
# -> 1101                   for f in a.fields]
#    1102         names = set([f.name for f in fields])
#    1103         for n in nfs:
#
# C:\spark\python\pyspark\sql\types.py in <listcomp>(.0)
#    1099         fields = [StructField(f.name, _merge_type(f.dataType, nfs.get(f.name, NullType()),
#    1100                                                   name=new_name(f.name)))
# -> 1101                   for f in a.fields]
#    1102         names = set([f.name for f in fields])
#    1103         for n in nfs:
#
# C:\spark\python\pyspark\sql\types.py in _merge_type(a, b, name)
#    1092     elif type(a) is not type(b):
#    1093         # TODO: type cast (such as int -> long)
# -> 1094         raise TypeError(new_msg("Can not merge type %s and %s" % (type(a), type(b))))
#    1095
#    1096     # same type
#
# TypeError: field did: Can not merge type <class 'pyspark.sql.types.DoubleType'> and <class 'pyspark.sql.types.LongType'>

# %%
stdDF_1.printSchema()
# Out:
# root
#  |-- sid: string (nullable = true)
#  |-- sname: string (nullable = true)
#  |-- did: long (nullable = true)

# %%
stdDF_1.rdd.getNumPartitions()
# Out:
# 8

# %%
df.select('ForecastSiteCode', 'ObservationTime', 'ObservationDate').show()
# Out:
# +----------------+---------------+-------------------+
# |ForecastSiteCode|ObservationTime|    ObservationDate|
# +----------------+---------------+-------------------+
# |            3002|              0|2016-02-01 05:00:00|
# |            3005|              0|2016-02-01 05:00:00|
# |            3008|              0|2016-02-01 05:00:00|
# |            3017|              0|2016-02-01 05:00:00|
# |            3023|              0|2016-02-01 05:00:00|
# |            3026|              0|2016-02-01 05:00:00|
# |            3031|              0|2016-02-01 05:00:00|
# |            3034|              0|2016-02-01 05:00:00|
# |            3037|              0|2016-02-01 05:00:00|
# |            3039|              0|2016-02-01 05:00:00|
# |            3041|              0|2016-02-01 05:00:00|
# |            3044|              0|2016-02-01 05:00:00|
# |            3047|              0|2016-02-01 05:00:00|
# |            3062|              0|2016-02-01 05:00:00|
# |            3063|              0|2016-02-01 05:00:00|
# |            3075|              0|2016-02-01 05:00:00|
# |            3066|              0|2016-02-01 05:00:00|
# |            3068|              0|2016-02-01 05:00:00|
# |            3080|              0|2016-02-01 05:00:00|
# |            3088|              0|2016-02-01 05:00:00|
# +----------------+---------------+-------------------+
# only showing top 20 rows

# %%
df.select('ForecastSiteCode', 'ObservationTime', 'ObservationDate').where(df.ForecastSiteCode>3075).show()
# Out:
# +----------------+---------------+-------------------+
# |ForecastSiteCode|ObservationTime|    ObservationDate|
# +----------------+---------------+-------------------+
# |            3080|              0|2016-02-01 05:00:00|
# |            3088|              0|2016-02-01 05:00:00|
# |            3091|              0|2016-02-01 05:00:00|
# |            3100|              0|2016-02-01 05:00:00|
# |            3105|              0|2016-02-01 05:00:00|
# |            3111|              0|2016-02-01 05:00:00|
# |            3134|              0|2016-02-01 05:00:00|
# |            3136|              0|2016-02-01 05:00:00|
# |            3155|              0|2016-02-01 05:00:00|
# |            3144|              0|2016-02-01 05:00:00|
# |            3148|              0|2016-02-01 05:00:00|
# |            3171|              0|2016-02-01 05:00:00|
# |            3132|              0|2016-02-01 05:00:00|
# |            3153|              0|2016-02-01 05:00:00|
# |            3158|              0|2016-02-01 05:00:00|
# |            3162|              0|2016-02-01 05:00:00|
# |            3166|              0|2016-02-01 05:00:00|
# |            3904|              0|2016-02-01 05:00:00|
# |            3907|              0|2016-02-01 05:00:00|
# |            3911|              0|2016-02-01 05:00:00|
# +----------------+---------------+-------------------+
# only showing top 20 rows

# %%
df.select('ForecastSiteCode', 'ObservationTime', 'ObservationDate').where('ForecastSiteCode>3088 and ObservationTime!=0').show()
# Out:
# +----------------+---------------+-------------------+
# |ForecastSiteCode|ObservationTime|    ObservationDate|
# +----------------+---------------+-------------------+
# |            3091|              1|2016-02-01 05:00:00|
# |            3100|              1|2016-02-01 05:00:00|
# |            3105|              1|2016-02-01 05:00:00|
# |            3111|              1|2016-02-01 05:00:00|
# |            3134|              1|2016-02-01 05:00:00|
# |            3136|              1|2016-02-01 05:00:00|
# |            3155|              1|2016-02-01 05:00:00|
# |            3148|              1|2016-02-01 05:00:00|
# |            3171|              1|2016-02-01 05:00:00|
# |            3132|              1|2016-02-01 05:00:00|
# |            3153|              1|2016-02-01 05:00:00|
# |            3158|              1|2016-02-01 05:00:00|
# |            3162|              1|2016-02-01 05:00:00|
# |            3166|              1|2016-02-01 05:00:00|
# |            3904|              1|2016-02-01 05:00:00|
# |            3907|              1|2016-02-01 05:00:00|
# |            3911|              1|2016-02-01 05:00:00|
# |            3915|              1|2016-02-01 05:00:00|
# |            3916|              1|2016-02-01 05:00:00|
# |            3917|              1|2016-02-01 05:00:00|
# +----------------+---------------+-------------------+
# only showing top 20 rows

# %%
df.select('ForecastSiteCode', 'ObservationTime', 'ObservationDate').where((df.ForecastSiteCode>3075) & (df.ObservationTime!=0)).show()
# Out:
# +----------------+---------------+-------------------+
# |ForecastSiteCode|ObservationTime|    ObservationDate|
# +----------------+---------------+-------------------+
# |            3080|              1|2016-02-01 05:00:00|
# |            3088|              1|2016-02-01 05:00:00|
# |            3091|              1|2016-02-01 05:00:00|
# |            3100|              1|2016-02-01 05:00:00|
# |            3105|              1|2016-02-01 05:00:00|
# |            3111|              1|2016-02-01 05:00:00|
# |            3134|              1|2016-02-01 05:00:00|
# |            3136|              1|2016-02-01 05:00:00|
# |            3155|              1|2016-02-01 05:00:00|
# |            3148|              1|2016-02-01 05:00:00|
# |            3171|              1|2016-02-01 05:00:00|
# |            3132|              1|2016-02-01 05:00:00|
# |            3153|              1|2016-02-01 05:00:00|
# |            3158|              1|2016-02-01 05:00:00|
# |            3162|              1|2016-02-01 05:00:00|
# |            3166|              1|2016-02-01 05:00:00|
# |            3904|              1|2016-02-01 05:00:00|
# |            3907|              1|2016-02-01 05:00:00|
# |            3911|              1|2016-02-01 05:00:00|
# |            3915|              1|2016-02-01 05:00:00|
# +----------------+---------------+-------------------+
# only showing top 20 rows

# %%
df.select('ForecastSiteCode','ObservationTime').where(df.ForecastSiteCode.isin(3911,3915)).show()
# Out:
# +----------------+---------------+
# |ForecastSiteCode|ObservationTime|
# +----------------+---------------+
# |            3911|              0|
# |            3915|              0|
# |            3911|              1|
# |            3915|              1|
# |            3911|              2|
# |            3915|              2|
# |            3911|              3|
# |            3915|              3|
# |            3911|              4|
# |            3915|              4|
# |            3911|              5|
# |            3915|              5|
# |            3911|              6|
# |            3915|              6|
# |            3911|              7|
# |            3915|              7|
# |            3911|              8|
# |            3915|              8|
# |            3911|              9|
# |            3915|              9|
# +----------------+---------------+
# only showing top 20 rows

# %%
df.select('ForecastSiteCode','ObservationTime').dropDuplicates().show()
# Out:
# +----------------+---------------+
# |ForecastSiteCode|ObservationTime|
# +----------------+---------------+
# |            3041|              0|
# |            3008|              1|
# |            3482|              2|
# |            3023|              4|
# |            3066|              5|
# |            3034|              7|
# |            3210|              7|
# |            3469|              8|
# |            3866|             10|
# |            3321|             11|
# |            3529|             13|
# |            3809|             15|
# |            3911|             16|
# |            3535|             16|
# |            3302|             21|
# |            3088|              0|
# |            3840|              0|
# |            3031|              1|
# |            3414|              1|
# |            3100|              3|
# +----------------+---------------+
# only showing top 20 rows

# %%
df.groupby('region').count().show()
# Out:
# +--------------------+-----+
# |              region|count|
# +--------------------+-----+
# |  North East England| 5673|
# |            Grampian| 8553|
# |   Orkney & Shetland| 5697|
# |               Wales|19704|
# |  Dumfries, Galloway| 7061|
# |  Yorkshire & Humber|12685|
# |London & South Ea...|24053|
# |     East of England| 9993|
# |         Strathclyde| 8561|
# |Central Tayside &...| 4265|
# |  South West England|23715|
# |Highland & Eilean...|16655|
# |  North West England|15352|
# |       East Midlands|11402|
# |       West Midlands| 9918|
# |    Northern Ireland|11410|
# +--------------------+-----+

# %%
from pyspark.sql import Row
from pyspark.sql.types import StructField, StructType, StringType, LongType, IntegerType
stdSchema = StructType([
StructField("sid", StringType(), True),
StructField("sname", StringType(), True),
StructField("did", IntegerType(), False)
])
stdRow = [Row("s1", "Ali", 1),Row("s2", "Ahmed", 1),Row("s3", "kareem", 2),Row("s4", "nouman", 3),Row("s5", "jameel", 3)]
stdDf = spark.createDataFrame(stdRow, stdSchema)
stdDf.show()
# Out:
# +---+------+---+
# |sid| sname|did|
# +---+------+---+
# | s1|   Ali|  1|
# | s2| Ahmed|  1|
# | s3|kareem|  2|
# | s4|nouman|  3|
# | s5|jameel|  3|
# +---+------+---+

# %%
deptSchema = StructType([
StructField("did", IntegerType(), True),
StructField("dname", StringType(), True),
StructField("add", StringType(), False)
])
deptRow = [Row(1, "CS", "B1"),Row(2, "BA", "B2"),Row(3, "EE", "B3"),Row(4, "Edu", "KC"),Row(5, "Math", "B3")]
deptDf = spark.createDataFrame(deptRow, deptSchema)
deptDf.show()
# Out:
# +---+-----+---+
# |did|dname|add|
# +---+-----+---+
# |  1|   CS| B1|
# |  2|   BA| B2|
# |  3|   EE| B3|
# |  4|  Edu| KC|
# |  5| Math| B3|
# +---+-----+---+

# %%
stdDf.createOrReplaceTempView("student")

# %%
deptDf.createOrReplaceTempView("dept")

# %%
spark.sql("select * from dept").show()
# Out:
# +---+------+---+
# |sid| sname|did|
# +---+------+---+
# | s1|   Ali|  1|
# | s2| Ahmed|  1|
# | s3|kareem|  2|
# | s4|nouman|  3|
# | s5|jameel|  3|
# +---+------+---+

# %%
spark.sql("select s.sid,s.sname,s.did,d.dname,d.add from student s, dept d where s.did=d.did").show()
# Out:
# +---+------+---+-----+---+
# |sid| sname|did|dname|add|
# +---+------+---+-----+---+
# | s1|   Ali|  1|   CS| B1|
# | s2| Ahmed|  1|   CS| B1|
# | s4|nouman|  3|   EE| B3|
# | s5|jameel|  3|   EE| B3|
# | s3|kareem|  2|   BA| B2|
# +---+------+---+-----+---+

# %%
columns = ['a','b','c','d']
val = [(1,'a1',12.0,'d1'),(1,'a2',1.2,'d2'),(1,'a3',12.0,'d3')]

newDF = spark.createDataFrame(val,columns)

# %%
newDF.show()
# Out:
# +---+---+----+---+
# |  a|  b|   c|  d|
# +---+---+----+---+
# |  1| a1|12.0| d1|
# |  1| a2| 1.2| d2|
# |  1| a3|12.0| d3|
# +---+---+----+---+

# %%
newDF.printSchema()
# Out:
# root
#  |-- a: long (nullable = true)
#  |-- b: string (nullable = true)
#  |-- c: double (nullable = true)
#  |-- d: string (nullable = true)

# %%
newDF.selectExpr('*', 'a+c as _sum').show()
# Out:
# +---+---+----+---+----+
# |  a|  b|   c|  d|_sum|
# +---+---+----+---+----+
# |  1| a1|12.0| d1|13.0|
# |  1| a2| 1.2| d2| 2.2|
# |  1| a3|12.0| d3|13.0|
# +---+---+----+---+----+

# %%
newDF.selectExpr('sum(a)', 'count(b)', 'avg(c)').show()
# Out:
# +------+--------+------+
# |sum(a)|count(b)|avg(c)|
# +------+--------+------+
# |     3|       3|   8.4|
# +------+--------+------+

# %%
newDF.createOrReplaceTempView('new')

# %%
spark.sql('select sum(a), count(b), avg(c) from new').show()
# Out:
# +------+--------+------+
# |sum(a)|count(b)|avg(c)|
# +------+--------+------+
# |     3|       3|   8.4|
# +------+--------+------+

# %%
newDF.summary()
# Out:
# DataFrame[summary: string, a: string, b: string, c: string, d: string]

# %%
newDF.filter(newDF.a>1).show()
# Out:
# +---+---+---+---+
# |  a|  b|  c|  d|
# +---+---+---+---+
# +---+---+---+---+

# %%
newDF.select(newDF.a,newDF.b).show()
# Out:
# +---+---+
# |  a|  b|
# +---+---+
# |  1| a1|
# |  1| a2|
# |  1| a3|
# +---+---+

# %% [markdown]
# #### Handling Duplicate Values

# %%
df22 = spark.createDataFrame([
(1, 144.5, 5.9, 33, 'M'),
(2, 167.2, 5.4, 45, 'M'),
(3, 124.1, 5.2, 23, 'F'),
(4, 144.5, 5.9, 33, 'M'),
(5, 133.2, 5.7, 54, 'F'),
(3, 124.1, 5.2, 23, 'F'),
(5, 129.2, 5.3, 42, 'M'),
], ['id', 'weight', 'height', 'age', 'gender'])

# %%
df22.show()
# Out:
# +---+------+------+---+------+
# | id|weight|height|age|gender|
# +---+------+------+---+------+
# |  1| 144.5|   5.9| 33|     M|
# |  2| 167.2|   5.4| 45|     M|
# |  3| 124.1|   5.2| 23|     F|
# |  4| 144.5|   5.9| 33|     M|
# |  5| 133.2|   5.7| 54|     F|
# |  3| 124.1|   5.2| 23|     F|
# |  5| 129.2|   5.3| 42|     M|
# +---+------+------+---+------+

# %%
df22.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- weight: double (nullable = true)
#  |-- height: double (nullable = true)
#  |-- age: long (nullable = true)
#  |-- gender: string (nullable = true)

# %%
df22.count()
# Out:
# 6

# %%
df22.distinct().count()
# Out:
# 5

# %%
df22 = df22.dropDuplicates()

# %%
df22.drop('id').distinct().count()
# Out:
# 5

# %%
column_list = [c for c in df22.columns if c != 'id']

# %%
column_list
# Out:
# ['weight', 'height', 'age', 'gender']

# %%
df22 = df22.dropDuplicates(c for c in df22.columns if c != 'id')

# %%
df22.select('id').distinct().count()
# Out:
# 4

# %%
df22.count()
# Out:
# 5

# %%
df22.withColumn('newID', F.monotonically_increasing_id()).show()
# Out:
# +---+------+------+---+------+-------------+
# | id|weight|height|age|gender|        newID|
# +---+------+------+---+------+-------------+
# |  5| 133.2|   5.7| 54|     F|  25769803776|
# |  1| 144.5|   5.9| 33|     M| 171798691840|
# |  2| 167.2|   5.4| 45|     M| 592705486848|
# |  3| 124.1|   5.2| 23|     F|1236950581248|
# |  5| 129.2|   5.3| 42|     M|1365799600128|
# +---+------+------+---+------+-------------+

# %%
df22.show()
# Out:
# +---+------+------+---+------+
# | id|weight|height|age|gender|
# +---+------+------+---+------+
# |  5| 133.2|   5.7| 54|     F|
# |  1| 144.5|   5.9| 33|     M|
# |  2| 167.2|   5.4| 45|     M|
# |  3| 124.1|   5.2| 23|     F|
# |  5| 129.2|   5.3| 42|     M|
# +---+------+------+---+------+

# %% [markdown]
# ###### Handling Missing Values

# %%
df_miss = spark.createDataFrame([
(1, 143.5, 5.6, 28, 'M', 100000),
(2, 167.2, 5.4, 45, 'M', None),
(3, None , 5.2, None, None, None),
(4, 144.5, 5.9, 33, 'M', None),
(5, 133.2, 5.7, 54, 'F', None),
(6, 124.1, 5.2, None, 'F', None),
(7, 129.2, 5.3, 42, 'M', 76000),
], ['id', 'weight', 'height', 'age', 'gender', 'income'])

# %%
df_miss.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- weight: double (nullable = true)
#  |-- height: double (nullable = true)
#  |-- age: long (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- income: long (nullable = true)

# %%
df_miss.show()
# Out:
# +---+------+------+----+------+------+
# | id|weight|height| age|gender|income|
# +---+------+------+----+------+------+
# |  1| 143.5|   5.6|  28|     M|100000|
# |  2| 167.2|   5.4|  45|     M|  null|
# |  3|  null|   5.2|null|  null|  null|
# |  4| 144.5|   5.9|  33|     M|  null|
# |  5| 133.2|   5.7|  54|     F|  null|
# |  6| 124.1|   5.2|null|     F|  null|
# |  7| 129.2|   5.3|  42|     M| 76000|
# +---+------+------+----+------+------+

# %%
df_miss.where(df_miss.weight.contains('None') | df_miss.weight.isNull() | df_miss.weight.contains('Null')).count()
# Out:
# 1

# %%
df_miss.where(df_miss.weight.isNull()).count()
# Out:
# 1

# %%
from pyspark.sql.functions import col,isnan,when,count
df_miss2 = df_miss.select([count(when(col(c).contains('None') | col(c).contains('NULL') | (col(c) == '' ) | col(c).isNull() |  isnan(c), c )).alias(c) for c in df_miss.columns]).show()
# Out:
# +---+------+------+---+------+------+
# | id|weight|height|age|gender|income|
# +---+------+------+---+------+------+
# |  0|     1|     0|  2|     1|     5|
# +---+------+------+---+------+------+

# %%
df_miss2 = df_miss.select([count(when(col(c).isNull(), c )).alias(c) for c in df_miss.columns]).show()
# Out:
# +---+------+------+---+------+------+
# | id|weight|height|age|gender|income|
# +---+------+------+---+------+------+
# |  0|     1|     0|  2|     1|     5|
# +---+------+------+---+------+------+

# %%
df_miss.select('age').count()
# Out:
# 7

# %%
df_miss.count()
# Out:
# 7

# %%
df_miss.select([(1 - (count(c) / count('*'))).alias(c + '_') for c in df_miss.columns]).show()
# Out:
# +---+------------------+-------+------------------+------------------+------------------+
# |id_|           weight_|height_|              age_|           gender_|           income_|
# +---+------------------+-------+------------------+------------------+------------------+
# |0.0|0.1428571428571429|    0.0|0.2857142857142857|0.1428571428571429|0.7142857142857143|
# +---+------------------+-------+------------------+------------------+------------------+

# %%
df_miss.select(*[count('age')]).show()
# Out:
# +----------+
# |count(age)|
# +----------+
# |         5|
# +----------+

# %%
df_miss.select([((count(c) / count('*'))).alias(c + '_missing') for c in df_miss.columns]).show()
# Out:
# +----------+------------------+--------------+------------------+------------------+------------------+
# |id_missing|    weight_missing|height_missing|       age_missing|    gender_missing|    income_missing|
# +----------+------------------+--------------+------------------+------------------+------------------+
# |       1.0|0.8571428571428571|           1.0|0.7142857142857143|0.8571428571428571|0.2857142857142857|
# +----------+------------------+--------------+------------------+------------------+------------------+

# %%
df_miss.dropna().show()
# Out:
# +---+------+------+---+------+------+
# | id|weight|height|age|gender|income|
# +---+------+------+---+------+------+
# |  1| 143.5|   5.6| 28|     M|100000|
# |  7| 129.2|   5.3| 42|     M| 76000|
# +---+------+------+---+------+------+

# %%
df_miss.dropna(thresh=3).show()
# Out:
# +---+------+------+----+------+------+
# | id|weight|height| age|gender|income|
# +---+------+------+----+------+------+
# |  1| 143.5|   5.6|  28|     M|100000|
# |  2| 167.2|   5.4|  45|     M|  null|
# |  4| 144.5|   5.9|  33|     M|  null|
# |  5| 133.2|   5.7|  54|     F|  null|
# |  6| 124.1|   5.2|null|     F|  null|
# |  7| 129.2|   5.3|  42|     M| 76000|
# +---+------+------+----+------+------+

# %%
df_miss.drop('income').drop('gender').columns
# Out:
# ['id', 'weight', 'height', 'age']

# %%
from pyspark.sql.functions import mean
means = df_miss.select([mean(c).alias(c) for c in df_miss.columns]).drop('income').toPandas()

# %%
means.at[0,'gender']='missing'

# %%
means
# Out:
#     id      weight    height   age   gender
# 0  4.0  140.283333  5.471429  40.4  missing

# %%
means = means.to_dict('records')[0]

# %%
means
# Out:
# {'age': 40.4,
#  'gender': 'missing',
#  'height': 5.471428571428571,
#  'id': 4.0,
#  'weight': 140.28333333333333}

# %%
df_miss.drop('income').fillna(means).show()
# Out:
# +---+------------------+------+---+-------+
# | id|            weight|height|age| gender|
# +---+------------------+------+---+-------+
# |  1|             143.5|   5.6| 28|      M|
# |  2|             167.2|   5.4| 45|      M|
# |  3|140.28333333333333|   5.2| 40|missing|
# |  4|             144.5|   5.9| 33|      M|
# |  5|             133.2|   5.7| 54|      F|
# |  6|             124.1|   5.2| 40|      F|
# |  7|             129.2|   5.3| 42|      M|
# +---+------------------+------+---+-------+

# %% [markdown]
# ###### Handling Outliers

# %%
df_outliers = spark.createDataFrame([
(1, 143.5, 5.3, 28),
(2, 154.2, 5.5, 45),
(3, 342.3, 5.1, 99),
(4, 144.5, 5.5, 33),
(5, 133.2, 5.4, 54),
(6, 124.1, 5.1, 21),
(7, 129.2, 5.3, 42),
], ['id', 'weight', 'height', 'age'])

# %%
cols = ['weight', 'height', 'age']
bounds = {}
for col in cols:
    quantiles = df_outliers.approxQuantile(col, [0.25, 0.75], 0.05)
    IQR = quantiles[1] - quantiles[0]
    bounds[col] = [quantiles[0] - 1.5 * IQR , quantiles[1] + 1.5 * IQR]

# %%
bounds
# Out:
# {'age': [-11.0, 93.0],
#  'height': [4.499999999999999, 6.1000000000000005],
#  'weight': [91.69999999999999, 191.7]}

# %%
outliers = df_outliers.select(['id'] + [((df_outliers[c] < bounds[c][0]) | (df_outliers[c] > bounds[c][1]) ).alias(c + '_o') for c in cols])
outliers.show()
# Out:
# +---+--------+--------+-----+
# | id|weight_o|height_o|age_o|
# +---+--------+--------+-----+
# |  7|   false|   false|false|
# |  6|   false|   false|false|
# |  5|   false|   false|false|
# |  1|   false|   false|false|
# |  3|    true|   false| true|
# |  2|   false|   false|false|
# |  4|   false|   false|false|
# +---+--------+--------+-----+

# %%
df_outliers = df_outliers.join(outliers, on='id')
df_outliers.filter('weight_o').select('id', 'weight').show()
df_outliers.filter('age_o').select('id', 'age').show()
# Out:
# +---+------+
# | id|weight|
# +---+------+
# |  3| 342.3|
# +---+------+
#
# +---+---+
# | id|age|
# +---+---+
# |  3| 99|
# +---+---+

# %%
df_outliers.filter('age_o').select('id', 'age').show()
# Out:
# +---+---+
# | id|age|
# +---+---+
# |  3| 99|
# +---+---+
